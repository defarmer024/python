# %%
import pandas as pd
df=pd.read_csv('Book1.csv',encoding='unicode_escape')

# %%
df.head()
# Out:
#    Gender   Gender1   Height   Weight   Weight1   No of People   \
# 0    Male          1    11.81    74.51     97.03              1
# 1    Male          1     3.85    54.66     86.62              6
# 2  Female          0     6.34    61.57     92.80              6
# 3    Male          1    10.38    51.53     62.45              1
# 4  Female          0     3.65    57.42     65.04              4
#
#    No of Events  Sick  Sick1      Smoking   ...  Belief_in_Afterlife   \
# 0              3  Yes       1       Never   ...                   No
# 1              3   No       0      Rarely   ...                   No
# 2              6  Yes       1  Moderately   ...                   No
# 3             10   No       0  Frequently   ...            Undecided
# 4              3   No       0       Never   ...            Undecided
#
#   Belief_in_Afterlife1     Political_Ideology  Political_Ideology1   \
# 0                    1  Slightly Conservative                     4
# ...

# %%
df2=df[['Weight ', 'Height ','Dose1']]
df2
#df.columns
# Out:
#     Weight   Height   Dose1
# 0     74.51    11.81     16
# 1     54.66     3.85     18
# 2     61.57     6.34     19
# 3     51.53    10.38     17
# 4     57.42     3.65     16
# 5     60.15     9.85     20
# 6     66.77     4.66     18
# 7     73.42     2.14     18
# 8     84.88     8.22     16
# 9     74.15     9.08     16
# 10    71.36    11.71     16
# 11    57.51     4.61     16
# 12    61.58    10.02     19
# 13    63.32     5.54     16
# 14    82.44     7.23     20
# 15    77.42     6.56     21
# 16    56.69    10.22     19
# 17    50.64    11.89     17
# 18    80.49    11.18     20
# 19    62.45     6.33     16
# 20    55.89     9.01     16
# 21    49.75     8.24     20
# 22    53.44     2.95     17
# 23    85.04     7.46     17
# 24    62.48     6.72     19
# 25    63.02     7.89     21
# 26    77.16    11.42     17
# 27    85.33    11.47     18
# 28    77.70    11.89     16
# 29    58.37     8.04     20
# 30    76.73     7.54     16
# 31    74.91     2.77     16
# ...

# %%
df.columns
# Out:
# Index(['Gender ', 'Gender1 ', 'Height ', 'Weight ', 'Weight1 ',
#        'No of People ', 'No of Events ', 'Sick', 'Sick1 ', 'Smoking ',
#        'Smoking1 ', 'Belief_in_Afterlife ', 'Belief_in_Afterlife1',
#        'Political_Ideology ', 'Political_Ideology1 ', 'Political_Party ',
#        'Political_Party1 ', 'Dose1', 'Dose2 ', 'Dose3 ', 'Dose4'],
#       dtype='object')

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
x=df2.values[:,range(0,2)]
y=df2.values[:,2]

# %%
model=LinearRegression().fit(x,y)

# %%
y_pred=model.predict(x)
#y_pred
df2['dose_pred']=y_pred
#df2.drop[:,'y_pred']
df2
# Out:
# <ipython-input-8-50ed3899080d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['dose_pred']=y_pred
#     Weight   Height   Dose1  dose_pred
# 0     74.51    11.81     16  17.839856
# 1     54.66     3.85     18  18.126488
# 2     61.57     6.34     19  18.018818
# 3     51.53    10.38     17  18.390314
# 4     57.42     3.65     16  18.049936
# 5     60.15     9.85     20  18.153885
# 6     66.77     4.66     18  17.837992
# 7     73.42     2.14     18  17.596309
# 8     84.88     8.22     16  17.472515
# 9     74.15     9.08     16  17.772442
# 10    71.36    11.71     16  17.918007
# 11    57.51     4.61     16  18.074582
# 12    61.58    10.02     19  18.121906
# 13    63.32     5.54     16  17.951374
# ...

# %%
print(model.intercept_)
# Out:
# 19.423204515846695

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df2['Height '],df2['Dose1'])

# %%
data=[[58,170],
     [34,156]]

# %%
model.predict(data)
# Out:
# array([22.7066084 , 22.93028098])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gender                40 non-null     object
#  1   Gender1               40 non-null     int64
#  2   Height                40 non-null     float64
#  3   Weight                40 non-null     float64
#  4   Weight1               40 non-null     float64
#  5   No of People          40 non-null     int64
#  6   No of Events          40 non-null     int64
#  7   Sick                  40 non-null     object
#  8   Sick1                 40 non-null     int64
#  9   Smoking               40 non-null     object
#  10  Smoking1              40 non-null     int64
#  11  Belief_in_Afterlife   40 non-null     object
#  12  Belief_in_Afterlife1  40 non-null     int64
#  13  Political_Ideology    40 non-null     object
#  14  Political_Ideology1   40 non-null     int64
# ...

# %%
#train and test set

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=45,test_size=0.2,shuffle=True)

# %%
x_test
# Out:
# array([[60.15,  9.85],
#        [63.32,  5.54],
#        [73.42,  2.14],
#        [74.51, 11.81],
#        [66.89, 11.08],
#        [55.89,  9.01],
#        [74.15,  9.08],
#        [62.45,  6.33]])

# %%
model=LinearRegression().fit(x_train,y_train)

# %%
model.coef_
# Out:
# array([-0.02801869,  0.03803384])

# %%
model.intercept_
# Out:
# 19.73583333562172

# %%
dose_pred=model.predict(x_test)

# %%
y_test
# Out:
# array([20., 16., 18., 16., 18., 16., 16., 16.])

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-e90483dda12a> in <module>
# ----> 1 df2['dose_pred']=dose_pred
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3897
#    3898             # turn me into an ndarray
# ...
